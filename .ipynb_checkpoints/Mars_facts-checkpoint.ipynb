# %%
import pandas as pd
from flask import Flask, render_template

# %%
app = Flask(__name__)

# Get html tables with pandas
url = 'https://space-facts.com/mars/'
tables = pd.read_html(url, header=0)
print(tables)
# Out:
# [   Equatorial Diameter:                       6,792 km
# 0       Polar Diameter:                       6,752 km
# 1                 Mass:  6.42 x 10^23 kg (10.7% Earth)
# 2                Moons:            2 (Phobos & Deimos)
# 3       Orbit Distance:       227,943,824 km (1.52 AU)
# 4         Orbit Period:           687 days (1.9 years)
# 5  Surface Temperature:                  -153 to 20 °C
# 6         First Record:              2nd millennium BC
# 7          Recorded By:           Egyptian astronomers]

# %% [markdown]
# # response = requests.get(url)
#
# # soup = bs(response.text, 'html.parser')

# %%
# print(soup.body.prettify())
# Out:
# <body id="astropedia">
#  <header>
#   <h1>
#    Astrogeology Science Center
#   </h1>
#   <a href="http://www.usgs.gov">
#    <img alt="USGS: Science for a Changing World" class="logo" height="70" src="/images/usgs_logo_main_2x.png" width="180"/>
#   </a>
#  </header>
#  <div class="wrapper">
#   <nav>
#    <a href="#" id="nav-toggle" title="Navigation Menu">
#     Menu
#    </a>
#    <ul class="dropdown dropdown-horizontal" id="yw0">
#     <li>
#      <a href="/">
#       Home
#      </a>
#     </li>
#     <li>
#      <a href="/about">
#       About
#      </a>
#      <ul>
#       <li>
#        <a href="/about/careers">
#         Careers
#        </a>
#       </li>
#       <li>
#        <a href="/contact">
#         Contact
#        </a>
#       </li>
#       <li>
#        <a href="/about/events">
#         Events
#        </a>
#       </li>
#       <li>
#        <a href="/site/glossary">
#         Glossary
#        </a>
#       </li>
#       <li>
#        <a href="/about/mission">
#         Mission
#        </a>
#       </li>
#       <li>
#        <a href="/news">
#         News
#        </a>
#       </li>
#       <li>
#        <a href="/people">
#         People
#        </a>
#       </li>
#       <li>
#        <a href="/about/using-our-images">
#         Using Our Images
#        </a>
#       </li>
#       <li>
#        <a href="/about/visitors">
#         Visitors
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/facilities">
#       Labs / Facilities
#      </a>
#      <ul>
#       <li>
#        <a href="/facilities/flynn-creek-crater-sample-collection">
#         Flynn Creek Crater Sample Collection
#        </a>
#       </li>
#       <li>
#        <a href="http://www.moon-cal.org">
#         Lunar Calibration Project
#        </a>
#       </li>
#       <li>
#        <a href="/facilities/meteor-crater-sample-collection">
#         Meteor Crater Sample Collection
#        </a>
#       </li>
#       <li>
#        <a href="/facilities/mrctr">
#         MRCTR GIS Lab
#        </a>
#       </li>
#       <li>
#        <a href="/facilities/cartography-and-imaging-sciences-node-of-nasa-planetary-data-system">
#         PDS Cartography and Imaging Sciences Node
#        </a>
#       </li>
#       <li>
#        <a href="/pds/annex">
#         PDS IMG Annex
#        </a>
#       </li>
#       <li>
#        <a href="/facilities/photogrammetry-guest-facility">
#         Photogrammetry Guest Facility
#        </a>
#       </li>
#       <li>
#        <a href="/rpif">
#         Regional Planetary Information Facility (RPIF)
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/maps">
#       Maps / Products
#      </a>
#      <ul>
#       <li>
#        <a href="/search">
#         Product Search
#        </a>
#       </li>
#       <li>
#        <a href="http://planetarynames.wr.usgs.gov">
#         Gazetteer of Planetary Nomenclature
#        </a>
#       </li>
#       <li>
#        <a href="http://planetarymapping.wr.usgs.gov">
#         Geologic Mapping Program
#        </a>
#       </li>
#       <li>
#        <a href="http://pilot.wr.usgs.gov">
#         Planetary Image Locator Tool (PILOT)
#        </a>
#       </li>
#       <li>
#        <a href="/search/planetary-index">
#         Planetary Map Index
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/geology">
#       Missions / Research
#      </a>
#      <ul>
#       <li>
#        <a href="/geology/mars-dunes">
#         Mars Dunes
#        </a>
#       </li>
#       <li>
#        <a href="/geology/mars-ice">
#         Mars Ice
#        </a>
#       </li>
#       <li>
#        <a href="/missions">
#         Mission Support
#        </a>
#       </li>
#       <li>
#        <a href="/solar-system">
#         Solar System
#        </a>
#       </li>
#       <li>
#        <a href="/groups">
#         Working Groups
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/tools">
#       Tools
#      </a>
#      <ul>
#       <li>
#        <a href="http://planetarynames.wr.usgs.gov">
#         Gazetteer of Planetary Nomenclature
#        </a>
#       </li>
#       <li>
#        <a href="http://isis.astrogeology.usgs.gov">
#         Integrated Software for Imagers and Spectrometers (ISIS)
#        </a>
#       </li>
#       <li>
#        <a href="http://astrogeology.usgs.gov/tools/map-a-planet-2">
#         Map a Planet 2
#        </a>
#       </li>
#       <li>
#        <a href="http://pilot.wr.usgs.gov">
#         Planetary Image Locator Tool (PILOT)
#        </a>
#       </li>
#       <li>
#        <a href="http://astrocloud.wr.usgs.gov/">
#         Projection on the Web (POW)
#        </a>
#       </li>
#      </ul>
#     </li>
#    </ul>
#    <form action="/search/results" class="search" id="search" method="get">
#     <input title="Search Astropedia" type="submit" value=""/>
#     <input name="q" placeholder="Search" type="text"/>
#     <input name="__ncforminfo" type="hidden" value="FoCLovPl8tCAlyu2AQqWCzVNSFZ_Q9h9XQM9_uKj1nlwQYxThDdDWz236efo95Lb1QJ6Uztr8PpUnz-zdjC8Tcp2X12QKSX0MuUawIjemVk="/>
#    </form>
#   </nav>
#   <div class="container">
#    <script>
#     var logo = "../astropedia/astropedia-logo-main.png"
#   var logoText = "Lunar and planetary cartographic catalog";
#   switch("") {
#   case 'PDS':
#       logo = "astropedia_annex_logo.png";
#       break;
#   case 'MRCTR':
#       logo = "mrctr_2x.jpg";
#       break;
#   };
#
# var stats=[{"mimetypes": [{"name": "isis", "count": 171.0}, {"name": "tiff", "count": 14.0}, {"name": "pdf", "count": 753.0}, {"name": "octet-stream", "count": 16.0}, {"name": "zip", "count": 13.0}, {"name": "jpeg", "count": 2096.0}, {"name": "png", "count": 1.0}], "count": 3064.0, "name": "Mars", "missions": [{"name": "Viking Orbiter", "count": 680.0}, {"name": "Mariner 9", "count": 18.0}, {"name": "Mars Odyssey", "count": 120.0}, {"name": "Mars Global Surveyor", "count": 31.0}, {"name": "Mars Express", "count": 14.0}, {"name": "Mars Reconnaissance Orbiter", "count": 52.0}, {"name": "Lunar Reconnaissance Orbiter", "count": 1.0}, {"name": "Mars Exploration Rover", "count": 2099.0}, {"name": "Mars Pathfinder", "count": 8.0}], "instruments": [{"name": "VIS", "count": 5.0}, {"name": "MOLA", "count": 94.0}, {"name": "THEMIS", "count": 2218.0}, {"name": "MOC", "count": 12.0}, {"name": "VISA", "count": 7.0}, {"name": "VISB", "count": 7.0}, {"name": "HRSC", "count": 31.0}, {"name": "HiRISE", "count": 5.0}, {"name": "CTX", "count": 50.0}, {"name": "HIRES", "count": 107.0}, {"name": "PANCAM", "count": 2099.0}, {"name": "Spirit", "count": 949.0}, {"name": "Opportunity", "count": 1149.0}, {"name": "TES", "count": 1.0}, {"name": "NAVCAM", "count": 1.0}, {"name": "HAZCAM", "count": 1.0}, {"name": "IMP", "count": 1.0}, {"name": "SSI", "count": 1.0}, {"name": "RAC", "count": 1.0}], "formats": [{"name": "Global Mosaic", "count": 83.0}, {"name": "Remote-sensing Data", "count": 60.0}, {"name": "Control Network", "count": 15.0}, {"name": "Raster Data", "count": 265.0}, {"name": "Document", "count": 82.0}, {"name": "Vector Data", "count": 114.0}, {"name": "Digital Elevation Model", "count": 30.0}, {"name": "Database", "count": 2.0}, {"name": "Grey Scale", "count": 5.0}, {"name": "Landing Site Map", "count": 50.0}, {"name": "Regional Mosaic", "count": 521.0}, {"name": "Merge", "count": 1.0}, {"name": "Topographic Map", "count": 7.0}, {"name": "Poster", "count": 2.0}, {"name": "Image", "count": 2099.0}, {"name": "Geologic Map", "count": 112.0}, {"name": "Polar Map", "count": 7.0}, {"name": "Shaded-Relief Map", "count": 89.0}, {"name": "Nomenclature", "count": 30.0}, {"name": "Globe", "count": 3.0}], "themes": [{"name": "Canyons", "count": 5.0}, {"name": "Cartography", "count": 716.0}, {"name": "Geomorphology", "count": 114.0}, {"name": "Image Processing", "count": 426.0}, {"name": "Remote Sensing", "count": 665.0}, {"name": "Solar system", "count": 46.0}, {"name": "Geographic Information System (GIS)", "count": 35.0}, {"name": "Craters", "count": 7.0}, {"name": "Geology", "count": 118.0}, {"name": "Volcanism", "count": 18.0}, {"name": "Exploration", "count": 1.0}, {"name": "Landing sites", "count": 63.0}, {"name": "Photogrammetry", "count": 62.0}, {"name": "Topography", "count": 198.0}, {"name": "Geophysical", "count": 49.0}, {"name": "Satellites", "count": 2.0}, {"name": "Structure", "count": 1.0}, {"name": "Water", "count": 5.0}, {"name": "Impact Crater", "count": 2.0}, {"name": "Hydrology", "count": 1.0}, {"name": "Photogeology", "count": 105.0}, {"name": "Stratigraphy", "count": 104.0}, {"name": "Planetary evolution", "count": 105.0}, {"name": "Regolith", "count": 1.0}, {"name": "Unmanned exploration", "count": 1.0}, {"name": "Roving vehicles", "count": 4.0}, {"name": "Photoclinometry", "count": 2.0}]}, {"mimetypes": [{"name": "octet-stream", "count": 25.0}, {"name": "jpeg", "count": 1247.0}, {"name": "gif", "count": 38.0}, {"name": "pdf", "count": 234.0}, {"name": "vnd.openxmlformats-officedocument.wordprocessingml.document", "count": 258.0}, {"name": "zip", "count": 22.0}, {"name": "png", "count": 20.0}, {"name": "tiff", "count": 15.0}, {"name": "isis", "count": 27.0}, {"name": "plain", "count": 5.0}, {"name": "x-gzip", "count": 4.0}, {"name": "vnd.ms-excel", "count": 2.0}, {"name": "html", "count": 158.0}, {"name": "vnd.ms-powerpoint", "count": 10.0}, {"name": "quicktime", "count": 1.0}, {"name": "vnd.openxmlformats-officedocument.presentati ...
#    </script>
#    <div id="pmi-header">
#     <div id="pmi-top-logo">
#      <div id="pmi-logo">
#       <div id="pmi-logo-text">
#        <script>
#         document.write(logoText);
#        </script>
#       </div>
#      </div>
#      <div id="pmi-scope">
#       <input id="pmi-scope-annex" name="pmi-scope-radio" onclick="toggleScope('PDS',true);" type="radio" value="PDS"/>
#       <label for="pmi-scope-annex">
#        Search PDS Annex
#       </label>
#       <br/>
#       <input id="pmi-scope-mrctr" name="pmi-scope-radio" onclick="toggleScope('MRCTR',true);" type="radio" value="MRCTR"/>
#       <label for="pmi-scope-mrctr">
#        Search MRCTR Geologic Maps
#       </label>
#       <br/>
#       <input checked="checked" id="pmi-scope-all" name="pmi-scope-radio" onclick="toggleScope('',true);" type="radio" value=""/>
#       <label for="pmi-scope-all">
#        Search all of Astrogeology
#       </label>
#      </div>
#     </div>
#     <div id="pmi-top-search">
#      <div id="pmi-top-buttons-title">
#       Search
#       <br/>
#       Filters
#      </div>
#      <div id="pmi-top-buttons">
#       <!--
#            <div class="pmi-top-button-block">
#               <input id="keyword" name="keyword" type="text" placeholder="Keyword" />
#            </div>
# -->
#       <div class="pmi-top-button-block">
#        <div class="pmi-checkbox-block">
#         <input id="gis-ready" name="gis-ready" type="checkbox"/>
#         <label for="gis-ready">
#          GIS ready
#         </label>
#        </div>
#       </div>
#       <div class="pmi-top-button-block">
#        <span class="pmi-top-detail">
#         Product Type
#        </span>
#        <select class="gray" id="formats-select" name="product type">
#         <option selected="selected" value="">
#          Product type
#         </option>
#        </select>
#       </div>
#       <div class="pmi-top-button-block">
#        <span class="pmi-top-detail">
#         Spacecraft
#        </span>
#        <select class="gray" id="missions-select" name="spacecraft">
#         <option selected="selected" value="">
#          Spacecraft
#         </option>
#        </select>
#       </div>
#       <!--
#            <div class="pmi-top-button-block">
#              <span class="pmi-top-detail">Theme</span>
#              <select id="themes-select" class="gray" name="theme">
#                  <option value="" selected="selected">Theme&nbsp;</option>
#              </select>
#            </div>
# -->
#       <div class="pmi-top-button-block" id="regions-select-block">
#        <span class="pmi-top-detail">
#         Region
#        </span>
#        <select class="gray" id="regions-select" name="region">
#         <option selected="selected" value="">
#          Region
#         </option>
#        </select>
#       </div>
#       <div class="pmi-top-button-block" id="features-select-block">
#        <span class="pmi-top-detail">
#         Feature Finder
#        </span>
#        <select class="gray" id="features-select" name="feature">
#         <option selected="selected" value="">
#          Feature
#         </option>
#        </select>
#       </div>
#       <div id="totalInfo">
#        Found
#        <br/>
#        Products:
#        <span id="totalCount">
#         0
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="pmi-page">
#     <div class="pmi-console" id="pmi-console">
#      <input id="scienceToggleHolder" name="scienceToggle" type="hidden" value="false"/>
#      <div id="planet-buttons">
#       <div id="targetInfoHeader">
#       </div>
#       <div id="planet-button-icons">
#        <div class="planet-button pluto" id="pluto-button">
#         <span>
#          PLUTO
#         </span>
#        </div>
#        <div class="planet-button neptune" id="neptune-button">
#         <span>
#          NEPTUNE
#         </span>
#        </div>
#        <div class="planet-button uranus" id="uranus-button">
#         <span>
#          URANUS
#         </span>
#        </div>
#        <div class="planet-button saturn" id="saturn-button">
#         <span>
#          SATURN
#         </span>
#        </div>
#        <div class="planet-button jupiter" id="jupiter-button">
#         <span>
#          JUPITER
#         </span>
#        </div>
#        <div class="planet-button small-bodies" id="small-bodies-button">
#         <span style="margin-top: 28px;">
#          SMALL BODIES
#         </span>
#        </div>
#        <div class="planet-button mars" id="mars-button">
#         <span>
#          MARS
#         </span>
#        </div>
#        <div class="planet-button earth" id="earth-button">
#         <span style="margin-top: 28px;">
#          MOON EARTH
#         </span>
#        </div>
#        <div class="planet-button venus" id="venus-button">
#         <span>
#          VENUS
#         </span>
#        </div>
#        <div class="planet-button mercury" id="mercury-button">
#         <span>
#          MERCURY
#         </span>
#        </div>
#       </div>
#      </div>
#      <div id="pmiSearch">
#       <form id="pmiSearchForm">
#        <input id="pmiKeywords" name="q" type="hidden" value=""/>
#        <input id="pmiSystems" name="system" type="hidden" value=""/>
#        <input id="pmiTargets" name="target" type="hidden" value=""/>
#        <input id="pmiMissions" name="mission" type="hidden" value=""/>
#        <input id="pmiAccessScope" name="access_scope" type="hidden" value=""/>
#        <input id="pmiFormats" name="geospatial_data_presentation_form" type="hidden" value=""/>
#        <input id="pmiThemes" name="theme" type="hidden" value=""/>
#        <input id="pmiQuadNames" name="quad_name" type="hidden" value=""/>
#        <input id="pmiInstruments" name="instrument" type="hidden" value=""/>
#        <input id="pmiMimetypes" name="mimetype" type="hidden" value=""/>
#        <input id="pmiMinimumLatitude" name="minimum_latitude" type="hidden" value=""/>
#        <input id="pmiMaximumLatitude" name="maximum_latitude" type="hidden" value=""/>
#        <input id="pmiMinimumLongitude" name="minimum_longitude" type="hidden" value=""/>
#        <input id="pmiMaximumLongitude" name="maximum_longitude" type="hidden" value=""/>
#        <input name="__ncforminfo" type="hidden" value="FoCLovPl8tCAlyu2AQqWCzVNSFZ_Q9h9XQM9_uKj1nlDbcg0e-8E4DcVCi4AvA26vAAURzjH0v6YnhWi0dX-4EfogVnrypiXC_jXbjvFdFjvQpKuy1Z_ILX7euSLWJa4NoNAtGHZzqHVrF8ineV1FGGqL4EZf2XiKPqB3J559F3BOQgl6NvgQnZZOvlXd3cDSDXhLIaKGRQYPvjCmG6PteT1O4r__RDN3RSRyTmGHbwWWWcuRonxfQ=="/>
#       </form>
#      </div>
#      <div id="pmi-target-info">
#      </div>
#      <div id="map" style="">
#      </div>
#      <div id="astroConsole">
#       <!--
#          <div class="upcSmallGray" style="margin-top:10px;" ><input type="button" id="pmiSetBounds" style="" value="Set" onclick="astroMap.boundingBoxDrawer.drawFromBounds(true);pilotConstrain.mapSearch();" />
#  bounding box below. . .<br/></div>
#           <div class="upcLatLonCenterBox" style="">Max Lat<br/><input type="text" id="astroBBTopLeftLat" size="10" value="" /></div>
#           <div class="upcLatLonLeftBox">Min Lon<br/><input type="text" id="astroBBTopLeftLon" size="10" value="" /></div>
#           <div class="upcLatLonRightBox">Max Lon<br/><input type="text" id="astroBBBotRightLon" size="10" value="" /></div>
#           <div class="upcLatLonCenterBox" >Min Lat<br/><input type="text" id="astroBBBotRightLat" size="10" value="" /></div>
#          <input type="hidden" name='astroBBWKT' id="astroBBWKT" onchange="astroMap.boundingBoxDrawer.drawFromForm();" />
#          <input type="hidden" name="queryType" value="intersects" />
#      </div>
#      <div style="float:right;">
#          <input type="button" name="upcClearBoundingBoxButton" id="pilotBBClear" style="margin: 10px 5px 0px 0px;" id="upcClearBoundingBoxButton" value="Clear Bounding Box" onclick="astroMap.boundingBoxDrawer.removeAndUnstoreAll();//pilotConstrain.mapSearch();" />
#         </div>
#     <div style="float:right;clear:both;margin-top:5px;">
#             <div class="upcSmallGray">Feature Finder</div><select id="upcFeatureType" onchange="call= new pilotAJAX('featureAjaxGet');call.loadFeatureNames(this.value);" ></select><select id="upcFeatureName" disabled="disabled" onchange="call= new pilotAJAX('featureLatLonAjaxGet');call.loadFeatureLatLon(this.value)" ></select>
#     </div>
# -->
#       <input id="astroBBTopLeftLat" name="pmiTopLeftLat" type="hidden" value=""/>
#       <input id="astroBBTopLeftLon" name="pmiTopLeftLon" type="hidden" value=""/>
#       <input id="astroBBBotRightLon" name="pmiBotRightLon" type="hidden" value=""/>
#       <input id="astroBBBotRightLat" name="pmiBotRightLat" type="hidden" value=""/>
#       <input id="astroBBWKT" name="astroBBWKT" type="hidden" value=""/>
#      </div>
#      <div id="pmi-projects">
#       <span id="projectTargetTitle">
#        Featured Pages:
#       </span>
#       <br/>
#       <div id="pmi-projects-results">
#       </div>
#      </div>
#      <!--
#   <div class="footer-title"><span id="footer-target"></span></div>
# -->
#     </div>
#     <div class="result-list" data-section="product" id="product-section">
#      <div id="rightPanel">
#       <div class="results" id="results">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="left">
#     <a href="http://astrogeology.usgs.gov">
#      Home
#     </a>
#     |
#     <a href="http://astrogeology.usgs.gov/contact">
#      Contact
#     </a>
#     |
#     <a href="http://astrogeology.usgs.gov/about/events">
#      Events
#     </a>
#     |
#     <a href="http://astrogeology.usgs.gov/news">
#      News
#     </a>
#    </div>
#    <div class="right">
#     <a href="http://www.doi.gov">
#      U.S. Department of Interior
#     </a>
#     |
#     <a href="http://www.usgs.gov">
#      U.S. Geological Survey
#     </a>
#     |
#     <a href="http://www.usa.gov">
#      USA.gov
#     </a>
#    </div>
#   </footer>
#  </div>
#  <!--
# 		<div class="credit">
# 			<small>Background Credits: NASA/USGS</small>
# 		</div>
# -->
#  <div class="page-background" style="
# 			background:url('/images/backgrounds/starfield.jpg');
# 			filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(
# 				src='/images/backgrounds/starfield.jpg', sizingMethod='scale');
# 		">
#  </div>
#  <script type="text/javascript">
#   var baseUrl = "";
#
#
# var _gaq = _gaq || [];_gaq.push(['_setAccount', 'UA-27613186-1']);_gaq.push(['_trackPageview']);(function() { var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js'; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);})();
#  </script>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js" type="text/javascript">
#  </script>
#  <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js" type="text/javascript">
#  </script>
#  <script src="/js/pmi.js" type="text/javascript">
#  </script>
#  <script src="https://astropedia.astrogeology.usgs.gov/downloadWeb/dynamic/glossary.js" type="text/javascript">
#  </script>
#  <script src="/js/astro-tips.js" type="text/javascript">
#  </script>
#  <script src="/js/general.js" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /*<![CDATA[*/
# showTooltips(".pmi-checkbox-block, .pmi-scope", true);
# /*]]>*/
#  </script>
# </body>

# %%
# results = soup.find('div', class_='container')
# print(results)
# content = soup.find('div', class_='rollover_description_inner')
# print(content.text)
# Out:
# <div class="container">
# <script>
#
#   var logo = "../astropedia/astropedia-logo-main.png"
#   var logoText = "Lunar and planetary cartographic catalog";
#   switch("") {
#   case 'PDS':
#       logo = "astropedia_annex_logo.png";
#       break;
#   case 'MRCTR':
#       logo = "mrctr_2x.jpg";
#       break;
#   };
#
# var stats=[{"mimetypes": [{"name": "isis", "count": 171.0}, {"name": "tiff", "count": 14.0}, {"name": "pdf", "count": 753.0}, {"name": "octet-stream", "count": 16.0}, {"name": "zip", "count": 13.0}, {"name": "jpeg", "count": 2096.0}, {"name": "png", "count": 1.0}], "count": 3064.0, "name": "Mars", "missions": [{"name": "Viking Orbiter", "count": 680.0}, {"name": "Mariner 9", "count": 18.0}, {"name": "Mars Odyssey", "count": 120.0}, {"name": "Mars Global Surveyor", "count": 31.0}, {"name": "Mars Express", "count": 14.0}, {"name": "Mars Reconnaissance Orbiter", "count": 52.0}, {"name": "Lunar Reconnaissance Orbiter", "count": 1.0}, {"name": "Mars Exploration Rover", "count": 2099.0}, {"name": "Mars Pathfinder", "count": 8.0}], "instruments": [{"name": "VIS", "count": 5.0}, {"name": "MOLA", "count": 94.0}, {"name": "THEMIS", "count": 2218.0}, {"name": "MOC", "count": 12.0}, {"name": "VISA", "count": 7.0}, {"name": "VISB", "count": 7.0}, {"name": "HRSC", "count": 31.0}, {"name": "HiRISE", "count": 5.0}, {"name": "CTX", "count": 50.0}, {"name": "HIRES", "count": 107.0}, {"name": "PANCAM", "count": 2099.0}, {"name": "Spirit", "count": 949.0}, {"name": "Opportunity", "count": 1149.0}, {"name": "TES", "count": 1.0}, {"name": "NAVCAM", "count": 1.0}, {"name": "HAZCAM", "count": 1.0}, {"name": "IMP", "count": 1.0}, {"name": "SSI", "count": 1.0}, {"name": "RAC", "count": 1.0}], "formats": [{"name": "Global Mosaic", "count": 83.0}, {"name": "Remote-sensing Data", "count": 60.0}, {"name": "Control Network", "count": 15.0}, {"name": "Raster Data", "count": 265.0}, {"name": "Document", "count": 82.0}, {"name": "Vector Data", "count": 114.0}, {"name": "Digital Elevation Model", "count": 30.0}, {"name": "Database", "count": 2.0}, {"name": "Grey Scale", "count": 5.0}, {"name": "Landing Site Map", "count": 50.0}, {"name": "Regional Mosaic", "count": 521.0}, {"name": "Merge", "count": 1.0}, {"name": "Topographic Map", "count": 7.0}, {"name": "Poster", "count": 2.0}, {"name": "Image", "count": 2099.0}, {"name": "Geologic Map", "count": 112.0}, {"name": "Polar Map", "count": 7.0}, {"name": "Shaded-Relief Map", "count": 89.0}, {"name": "Nomenclature", "count": 30.0}, {"name": "Globe", "count": 3.0}], "themes": [{"name": "Canyons", "count": 5.0}, {"name": "Cartography", "count": 716.0}, {"name": "Geomorphology", "count": 114.0}, {"name": "Image Processing", "count": 426.0}, {"name": "Remote Sensing", "count": 665.0}, {"name": "Solar system", "count": 46.0}, {"name": "Geographic Information System (GIS)", "count": 35.0}, {"name": "Craters", "count": 7.0}, {"name": "Geology", "count": 118.0}, {"name": "Volcanism", "count": 18.0}, {"name": "Exploration", "count": 1.0}, {"name": "Landing sites", "count": 63.0}, {"name": "Photogrammetry", "count": 62.0}, {"name": "Topography", "count": 198.0}, {"name": "Geophysical", "count": 49.0}, {"name": "Satellites", "count": 2.0}, {"name": "Structure", "count": 1.0}, {"name": "Water", "count": 5.0}, {"name": "Impact Crater", "count": 2.0}, {"name": "Hydrology", "count": 1.0}, {"name": "Photogeology", "count": 105.0}, {"name": "Stratigraphy", "count": 104.0}, {"name": "Planetary evolution", "count": 105.0}, {"name": "Regolith", "count": 1.0}, {"name": "Unmanned exploration", "count": 1.0}, {"name": "Roving vehicles", "count": 4.0}, {"name": "Photoclinometry", "count": 2.0}]}, {"mimetypes": [{"name": "octet-stream", "count": 25.0}, {"name": "jpeg", "count": 1247.0}, {"name": "gif", "count": 38.0}, {"name": "pdf", "count": 234.0}, {"name": "vnd.openxmlformats-officedocument.wordprocessingml.document", "count": 258.0}, {"name": "zip", "count": 22.0}, {"name": "png", "count": 20.0}, {"name": "tiff", "count": 15.0}, {"name": "isis", "count": 27.0}, {"name": "plain", "count": 5.0}, {"name": "x-gzip", "count": 4.0}, {"name": "vnd.ms-excel", "count": 2.0}, {"name": "html", "count": 158.0}, {"name": "vnd.ms-powerpoint", "count": 10.0}, {"name": "quicktime", "count": 1.0}, {"name": "vnd.openxmlformats-officedocument.presentati ...
#
# </script>
# <div id="pmi-header">
# <div id="pmi-top-logo">
# <div id="pmi-logo">
# <div id="pmi-logo-text">
# <script>document.write(logoText);</script>
# </div>
# </div>
# <div id="pmi-scope">
# <input id="pmi-scope-annex" name="pmi-scope-radio" onclick="toggleScope('PDS',true);" type="radio" value="PDS"/>
# <label for="pmi-scope-annex">Search PDS Annex</label><br/>
# <input id="pmi-scope-mrctr" name="pmi-scope-radio" onclick="toggleScope('MRCTR',true);" type="radio" value="MRCTR"/>
# <label for="pmi-scope-mrctr">Search MRCTR Geologic Maps</label><br/>
# <input checked="checked" id="pmi-scope-all" name="pmi-scope-radio" onclick="toggleScope('',true);" type="radio" value=""/>
# <label for="pmi-scope-all">Search all of Astrogeology</label>
# </div>
# </div>
# <div id="pmi-top-search">
# <div id="pmi-top-buttons-title">Search<br/>Filters</div>
# <div id="pmi-top-buttons">
# <!--
#            <div class="pmi-top-button-block">
#               <input id="keyword" name="keyword" type="text" placeholder="Keyword" />
#            </div>
# -->
# <div class="pmi-top-button-block">
# <div class="pmi-checkbox-block">
# <input id="gis-ready" name="gis-ready" type="checkbox"/>
# <label for="gis-ready">GIS ready</label>
# </div>
# </div>
# <div class="pmi-top-button-block">
# <span class="pmi-top-detail">Product Type</span>
# <select class="gray" id="formats-select" name="product type">
# <option selected="selected" value="">Product type </option>
# </select>
# </div>
# <div class="pmi-top-button-block">
# <span class="pmi-top-detail">Spacecraft</span>
# <select class="gray" id="missions-select" name="spacecraft">
# <option selected="selected" value="">Spacecraft </option>
# </select>
# </div>
# <!--
#            <div class="pmi-top-button-block">
#              <span class="pmi-top-detail">Theme</span>
#              <select id="themes-select" class="gray" name="theme">
#                  <option value="" selected="selected">Theme&nbsp;</option>
#              </select>
#            </div>
# -->
# <div class="pmi-top-button-block" id="regions-select-block">
# <span class="pmi-top-detail">Region</span>
# <select class="gray" id="regions-select" name="region">
# <option selected="selected" value="">Region </option>
# </select>
# </div>
# <div class="pmi-top-button-block" id="features-select-block">
# <span class="pmi-top-detail">Feature Finder</span>
# <select class="gray" id="features-select" name="feature">
# <option selected="selected" value="">Feature </option>
# </select>
# </div>
# <div id="totalInfo">
#                 Found<br/>Products: <span id="totalCount">0</span>
# </div>
# </div>
# </div>
# </div>
# <div id="pmi-page">
# <div class="pmi-console" id="pmi-console">
# <input id="scienceToggleHolder" name="scienceToggle" type="hidden" value="false"/>
# <div id="planet-buttons">
# <div id="targetInfoHeader"></div>
# <div id="planet-button-icons">
# <div class="planet-button pluto" id="pluto-button"><span>PLUTO</span></div>
# <div class="planet-button neptune" id="neptune-button"><span>NEPTUNE</span></div>
# <div class="planet-button uranus" id="uranus-button"><span>URANUS</span></div>
# <div class="planet-button saturn" id="saturn-button"><span>SATURN</span></div>
# <div class="planet-button jupiter" id="jupiter-button"><span>JUPITER</span></div>
# <div class="planet-button small-bodies" id="small-bodies-button"><span style="margin-top: 28px;">SMALL BODIES</span></div>
# <div class="planet-button mars" id="mars-button"><span>MARS</span></div>
# <div class="planet-button earth" id="earth-button"><span style="margin-top: 28px;">MOON EARTH</span></div>
# <div class="planet-button venus" id="venus-button"><span>VENUS</span></div>
# <div class="planet-button mercury" id="mercury-button"><span>MERCURY</span></div>
# </div>
# </div>
# <div id="pmiSearch">
# <form id="pmiSearchForm">
# <input id="pmiKeywords" name="q" type="hidden" value=""/>
# <input id="pmiSystems" name="system" type="hidden" value=""/>
# <input id="pmiTargets" name="target" type="hidden" value=""/>
# <input id="pmiMissions" name="mission" type="hidden" value=""/>
# <input id="pmiAccessScope" name="access_scope" type="hidden" value=""/>
# <input id="pmiFormats" name="geospatial_data_presentation_form" type="hidden" value=""/>
# <input id="pmiThemes" name="theme" type="hidden" value=""/>
# <input id="pmiQuadNames" name="quad_name" type="hidden" value=""/>
# <input id="pmiInstruments" name="instrument" type="hidden" value=""/>
# <input id="pmiMimetypes" name="mimetype" type="hidden" value=""/>
# <input id="pmiMinimumLatitude" name="minimum_latitude" type="hidden" value=""/>
# <input id="pmiMaximumLatitude" name="maximum_latitude" type="hidden" value=""/>
# <input id="pmiMinimumLongitude" name="minimum_longitude" type="hidden" value=""/>
# <input id="pmiMaximumLongitude" name="maximum_longitude" type="hidden" value=""/>
# <input name="__ncforminfo" type="hidden" value="FoCLovPl8tCAlyu2AQqWCzVNSFZ_Q9h9XQM9_uKj1nlDbcg0e-8E4DcVCi4AvA26vAAURzjH0v6YnhWi0dX-4EfogVnrypiXC_jXbjvFdFjvQpKuy1Z_ILX7euSLWJa4NoNAtGHZzqHVrF8ineV1FGGqL4EZf2XiKPqB3J559F3BOQgl6NvgQnZZOvlXd3cDSDXhLIaKGRQYPvjCmG6PteT1O4r__RDN3RSRyTmGHbwWWWcuRonxfQ=="/></form>
# </div>
# <div id="pmi-target-info"></div>
# <div id="map" style=""></div>
# <div id="astroConsole">
# <!--
#          <div class="upcSmallGray" style="margin-top:10px;" ><input type="button" id="pmiSetBounds" style="" value="Set" onclick="astroMap.boundingBoxDrawer.drawFromBounds(true);pilotConstrain.mapSearch();" />
#  bounding box below. . .<br/></div>
#           <div class="upcLatLonCenterBox" style="">Max Lat<br/><input type="text" id="astroBBTopLeftLat" size="10" value="" /></div>
#           <div class="upcLatLonLeftBox">Min Lon<br/><input type="text" id="astroBBTopLeftLon" size="10" value="" /></div>
#           <div class="upcLatLonRightBox">Max Lon<br/><input type="text" id="astroBBBotRightLon" size="10" value="" /></div>
#           <div class="upcLatLonCenterBox" >Min Lat<br/><input type="text" id="astroBBBotRightLat" size="10" value="" /></div>
#          <input type="hidden" name='astroBBWKT' id="astroBBWKT" onchange="astroMap.boundingBoxDrawer.drawFromForm();" />
#          <input type="hidden" name="queryType" value="intersects" />
#      </div>
#      <div style="float:right;">
#          <input type="button" name="upcClearBoundingBoxButton" id="pilotBBClear" style="margin: 10px 5px 0px 0px;" id="upcClearBoundingBoxButton" value="Clear Bounding Box" onclick="astroMap.boundingBoxDrawer.removeAndUnstoreAll();//pilotConstrain.mapSearch();" />
#         </div>
#     <div style="float:right;clear:both;margin-top:5px;">
#             <div class="upcSmallGray">Feature Finder</div><select id="upcFeatureType" onchange="call= new pilotAJAX('featureAjaxGet');call.loadFeatureNames(this.value);" ></select><select id="upcFeatureName" disabled="disabled" onchange="call= new pilotAJAX('featureLatLonAjaxGet');call.loadFeatureLatLon(this.value)" ></select>
#     </div>
# -->
# <input id="astroBBTopLeftLat" name="pmiTopLeftLat" type="hidden" value=""/>
# <input id="astroBBTopLeftLon" name="pmiTopLeftLon" type="hidden" value=""/>
# <input id="astroBBBotRightLon" name="pmiBotRightLon" type="hidden" value=""/>
# <input id="astroBBBotRightLat" name="pmiBotRightLat" type="hidden" value=""/>
# <input id="astroBBWKT" name="astroBBWKT" type="hidden" value=""/>
# </div>
# <div id="pmi-projects">
# <span id="projectTargetTitle">Featured Pages:</span><br/>
# <div id="pmi-projects-results"></div>
# </div>
# <!--
#   <div class="footer-title"><span id="footer-target"></span></div>
# -->
# </div>
# <div class="result-list" data-section="product" id="product-section">
# <div id="rightPanel">
# <div class="results" id="results"> </div>
# </div>
# </div>
# </div>
# </div>
